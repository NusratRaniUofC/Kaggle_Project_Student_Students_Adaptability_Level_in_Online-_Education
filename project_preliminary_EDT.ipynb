# %%
# Core
import pandas as pd
import numpy as np

# Visualization
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# To avoid warnings
import warnings
warnings.filterwarnings("ignore") # 😃

# %%
import pandas as pd

data = pd.read_csv("students_adaptability_level_online_education.csv")
data
# Out:
#      Gender    Age Education Level Institution Type IT Student Location  \
# 0       Boy  21-25      University   Non Government         No      Yes
# 1      Girl  21-25      University   Non Government         No      Yes
# 2      Girl  16-20         College       Government         No      Yes
# 3      Girl  11-15          School   Non Government         No      Yes
# 4      Girl  16-20          School   Non Government         No      Yes
# ...     ...    ...             ...              ...        ...      ...
# 1200   Girl  16-20         College   Non Government         No      Yes
# 1201   Girl  16-20         College   Non Government         No       No
# 1202    Boy  11-15          School   Non Government         No      Yes
# 1203   Girl  16-20         College   Non Government         No       No
# 1204   Girl  11-15          School   Non Government         No      Yes
#
#      Load-shedding Financial Condition Internet Type Network Type  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1205 entries, 0 to 1204
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Gender               1205 non-null   object
#  1   Age                  1205 non-null   object
#  2   Education Level      1205 non-null   object
#  3   Institution Type     1205 non-null   object
#  4   IT Student           1205 non-null   object
#  5   Location             1205 non-null   object
#  6   Load-shedding        1205 non-null   object
#  7   Financial Condition  1205 non-null   object
#  8   Internet Type        1205 non-null   object
#  9   Network Type         1205 non-null   object
#  10  Class Duration       1205 non-null   object
#  11  Self Lms             1205 non-null   object
#  12  Device               1205 non-null   object
#  13  Adaptivity Level     1205 non-null   object
# dtypes: object(14)
# memory usage: 131.9+ KB

# %%
cols_cat = list(data.select_dtypes(include = ["object"]))

# %%
cols_cat
# Out:
# ['Gender',
#  'Age',
#  'Education Level',
#  'Institution Type',
#  'IT Student',
#  'Location',
#  'Load-shedding',
#  'Financial Condition',
#  'Internet Type',
#  'Network Type',
#  'Class Duration',
#  'Self Lms',
#  'Device',
#  'Adaptivity Level']

# %%
for i in cols_cat:
    sns.countplot(data = data, x = i, hue = "Adaptivity Level")
    plt.title(i)
    plt.show()

# %%
plt.figure(figsize = (10,7))
sns.heatmap(data = data.corr(), vmin = -1, vmax = 1, annot = True, cmap = "Spectral");

# %%
data.corr()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
data["Education Level"].describe()
# Out:
# count       1205
# unique         3
# top       School
# freq         530
# Name: Education Level, dtype: object

# %%
data["Education Level"] = data["Education Level"].astype("category")

# %%
data["Education Level"].describe()
# Out:
# count       1205
# unique         3
# top       School
# freq         530
# Name: Education Level, dtype: object

# %%
data["Adaptivity Level"].describe()
# Out:
# count         1205
# unique           3
# top       Moderate
# freq           625
# Name: Adaptivity Level, dtype: object

# %%
df = data.astype({"Education Level":'category', "Age":'int64'})

# %%
df = data.astype({"Education Level":'category'})
data["Adaptivity Level"].describe()
# Out:
# count         1205
# unique           3
# top       Moderate
# freq           625
# Name: Adaptivity Level, dtype: object

# %%
# Core
import pandas as pd
import numpy as np

# Visualization
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# To avoid warnings
import warnings
warnings.filterwarnings("ignore")

# %%
# df = pd.DataFrame({
#     'length': [1.5, 0.5, 1.2, 0.9, 3],
#     'width': [0.7, 0.2, 0.15, 0.2, 1.1]
#     }, index=['pig', 'rabbit', 'duck', 'chicken', 'horse'])
# #df

hist = data.hist(bins=3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-8cd14b3b9cc5> in <module>
#       4 #     }, index=['pig', 'rabbit', 'duck', 'chicken', 'horse'])
#       5 # #df
# ----> 6 hist = data.hist(bins=3)
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, backend, legend, **kwargs)
#     209     """
#     210     plot_backend = _get_plot_backend(backend)
# --> 211     return plot_backend.hist_frame(
#     212         data,
#     213         column=column,
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\hist.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, legend, **kwds)
#     425
#     426     if naxes == 0:
# --> 427         raise ValueError(
# ...

# %%
data.hist(figsize = (20,20))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-89d1c268eddf> in <module>
# ----> 1 data.hist(figsize = (20,20))
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, backend, legend, **kwargs)
#     209     """
#     210     plot_backend = _get_plot_backend(backend)
# --> 211     return plot_backend.hist_frame(
#     212         data,
#     213         column=column,
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\hist.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, legend, **kwds)
#     425
#     426     if naxes == 0:
# --> 427         raise ValueError(
#     428             "hist method requires numerical or datetime columns, nothing to plot."
# ...

# %% [markdown]
# # Handling missing daata:
#
# data.select_dtypes('number').fillna(0)
# data.select_dtypes('number').fillna(data.median())
